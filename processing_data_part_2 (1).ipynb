# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %matplotlib inline

# %%
airlines = pd.read_csv('flight-delays/airlines.csv')
airlines.shape
# Out:
# (14, 2)

# %%
airlines.head(1)
# Out:
#   IATA_CODE                AIRLINE
# 0        UA  United Air Lines Inc.

# %%
flights = pd.read_csv('flight-delays/clean_flights.csv')
flights.shape
# Out:
# (5819079, 31)

# %%
flights.head(1)
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 0         408.0          -22.0         0          0                  NaN
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY
# 0            NaN
#
# [1 rows x 31 columns]

# %%
airports = pd.read_csv('flight-delays/airports.csv')
airports.shape
# Out:
# (322, 7)

# %%
airports.head(1)
# Out:
#   IATA_CODE                              AIRPORT       CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport  Allentown    PA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236   -75.4404

# %% [markdown]
# ### Create column for date

# %%
# first creat method edit that fix numbers format, e.g: 1 -> 01

def edit_number(num):
    if len(num) == 1:
        return '0'+ str(num)
    else:
        return num

# %%
flights['MONTH'] = flights['MONTH'].apply(lambda x: edit_number(str(x)))
flights['DAY'] = flights['DAY'].apply(lambda x: edit_number(str(x)))

flights.sample(3)
# Out:
#          YEAR MONTH DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5504332  2015    10  11            7      B6           1654      N635JB
# 2823809  2015    06  26            5      OO           2845      N869AS
# 5360480  2015    10  02            5      DL            456      N698DL
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 5504332            SJU                 FLL                 2034
# 2823809            LAX                 SJC                 2155
# 5360480            JFK                 SLC                 1600
#
#              ...        ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 5504332      ...              2302.0           -6.0         0          0
# 2823809      ...                47.0          101.0         0          0
# 5360480      ...              2003.0           43.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 5504332                  NaN               NaN             NaN            NaN
# 2823809                  NaN               1.0             0.0            0.0
# 5360480                  NaN              26.0             0.0           17.0
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 5504332                  NaN            NaN
# 2823809                100.0            0.0
# 5360480                  0.0            0.0
#
# [3 rows x 31 columns]

# %%
flights['date'] = flights[['YEAR','MONTH','DAY']].apply(lambda row: str(row['DAY'])\
                            +'/'+str(row['MONTH'])+'/'+str(row['YEAR']),axis=1)

# %%
flights.sample(3)
# Out:
#          YEAR MONTH DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 4793278  2015    11  27            5      WN           5594      N647SW
# 3969079  2015    09  03            4      B6             90      N562JB
# 116230   2015    01  08            4      MQ           3530      N537MQ
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE     ...      \
# 4793278            ATL                 PBI                  955     ...
# 3969079            SAN                 JFK                 2041     ...
# 116230             CVG                 ORD                 1136     ...
#
#          ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 4793278            0.0         0          0                  NaN
# 3969079            0.0         0          0                  NaN
# 116230           160.0         0          0                  NaN
#
#          AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 4793278               NaN             NaN            NaN                  NaN
# 3969079               NaN             NaN            NaN                  NaN
# 116230              111.0             0.0            0.0                 49.0
#
#          WEATHER_DELAY        date
# 4793278            NaN  27/11/2015
# 3969079            NaN  03/09/2015
# 116230             0.0  08/01/2015
#
# [3 rows x 32 columns]

# %%
flights['date'].dtypes
# Out:
# dtype('O')

# %%
#  convert date column type from object to date 

flights['date'] = flights.apply(lambda row: datetime.strptime(row['date'], '%d/%m/%Y'),axis=1)

flights['date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
flights.sample(3)
# Out:
#          YEAR MONTH DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 1030436  2015    03  09            1      EV           5121      N730EV
# 2969712  2015    07  06            1      AA            248      N4YPAA
# 1176554  2015    03  18            3      WN            884      N764SW
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE    ...      \
# 1030436            LGA                 ROC                  850    ...
# 2969712            DFW                 BNA                  700    ...
# 1176554            PIT                 PHX                  715    ...
#
#          ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 1030436            7.0         0          0                  NaN
# 2969712           -1.0         0          0                  NaN
# 1176554          -31.0         0          0                  NaN
#
#          AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 1030436               NaN             NaN            NaN                  NaN
# 2969712               NaN             NaN            NaN                  NaN
# 1176554               NaN             NaN            NaN                  NaN
#
#          WEATHER_DELAY       date
# 1030436            NaN 2015-03-09
# 2969712            NaN 2015-07-06
# 1176554            NaN 2015-03-18
#
# [3 rows x 32 columns]

# %% [markdown]
# ### Define a flag column for delay

# %%
# Define a flag column for delay (Departure or Arrival) : 15 Mints >=

flights['delayed'] = flights.apply(lambda x:1 if(x['ARRIVAL_DELAY']>=15 or x['DEPARTURE_DELAY']>=15) else 0,axis=1)

# %% [markdown]
# ### Define a flag column Shift (Morning, Afternoon, Noon, Night)

# %%
# Combine flights per shift and apply it to data frame
def Day_Shift(x):
    if x in range(500,1200):
        return 'Morninig'
    elif x in range(1201,1700):
        return 'Afternoon'
    elif x in range(1701,2100):
        return 'Evening'
    else:
        return 'Night'
    
flights['FlightsShift'] = flights['SCHEDULED_DEPARTURE'].apply(Day_Shift)
flights.head(1)
# Out:
#    YEAR MONTH DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015    01  01            4      AS             98      N407AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...       \
# 0            ANC                 SEA                    5      ...
#
#    CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# 0          0                  NaN               NaN             NaN
#
#    AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY       date  delayed  \
# 0            NaN                  NaN            NaN 2015-01-01        0
#
#    FlightsShift
# 0         Night
#
# [1 rows x 34 columns]

# %% [markdown]
# ### Define a flag column Seasons
#
# #### Seasons are:
# 1. Winter: December, January, and Fibruary.
# 2. Spring: March, April, and May.
# 3. Summer: June, July, and August.
# 4. Autumn: September, October, and November.

# %%
# Determine Season for each Flight

def Year_Shift(x):
    if ((x == '03') or (x == '04') or (x == '05')):
        return 'Spring'
    elif ((x == '06') or (x == '07') or (x == '08')):
        return 'Summer'
    elif ((x == '09') or (x == '10') or (x == '11')):
        return 'Autumn'
    elif ((x == '12') or (x == '01') or (x == '02')):
        return 'Winter'
    
flights['SEASON'] = flights['MONTH'].apply(Year_Shift)
flights.head(5)
# Out:
#    YEAR MONTH DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015    01  01            4      AS             98      N407AS
# 1  2015    01  01            4      AA           2336      N3KUAA
# 2  2015    01  01            4      US            840      N171US
# 3  2015    01  01            4      AA            258      N3HYAA
# 4  2015    01  01            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE   ...    \
# 0            ANC                 SEA                    5   ...
# 1            LAX                 PBI                   10   ...
# 2            SFO                 CLT                   20   ...
# 3            LAX                 MIA                   20   ...
# 4            SEA                 ANC                   25   ...
#
#    CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 0                  NaN               NaN             NaN            NaN
# 1                  NaN               NaN             NaN            NaN
# 2                  NaN               NaN             NaN            NaN
# 3                  NaN               NaN             NaN            NaN
# 4                  NaN               NaN             NaN            NaN
#
#    LATE_AIRCRAFT_DELAY  WEATHER_DELAY       date  delayed  FlightsShift  \
# 0                  NaN            NaN 2015-01-01        0         Night
# 1                  NaN            NaN 2015-01-01        0         Night
# 2                  NaN            NaN 2015-01-01        0         Night
# 3                  NaN            NaN 2015-01-01        0         Night
# 4                  NaN            NaN 2015-01-01        0         Night
#
#    SEASON
# 0  Winter
# 1  Winter
# 2  Winter
# 3  Winter
# 4  Winter
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Full dataset
#
# xxxxxxxxx

# %%
airports = airports.drop('COUNTRY',axis=1)
airports.columns

# %%
# join the airports info with flights info

left = flights
right = airports
right.columns = ['ORIGIN_AIRPORT', 'ORIGIN_AIRPORT_NAME', 'ORIGIN_CITY',\
                 'ORIGIN_STATE', 'ORIGIN_LATITUDE', 'ORIGIN_LONGITUDE']
full_data = pd.merge(left, right, how='left', on='ORIGIN_AIRPORT')

full_data.shape
# 5819079
# Out:
# (5819079, 40)

# %%
# join the airports info with flights info

left = full_data
right = airports
right.columns = ['DESTINATION_AIRPORT', 'DESTINATION_AIRPORT_NAME', 'DESTINATION_CITY',\
                 'DESTINATION_STATE', 'DESTINATION_LATITUDE', 'DESTINATION_LONGITUDE']
full_data = pd.merge(left, right, how='left', on='DESTINATION_AIRPORT')

full_data.shape
# 5819079
# Out:
# (5819079, 45)

# %%
# join the airlines info with flights info

left = full_data
right = airlines
right.columns = ['AIRLINE','AIRLINE NAME']
full_data = pd.merge(left, right, how='left', on='AIRLINE')

full_data.shape
# 5819079
# Out:
# (5819079, 46)

# %%
# save the full_data in CSV file

url = '../ML-Project/flight-delays/full_data.csv'

full_data.to_csv(url,index=False)
